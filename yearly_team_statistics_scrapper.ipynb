# %%
# %config Completer.use_jedi = False

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import datetime
import time

# %%
BASE_URL = "https://www.baseball-reference.com/leagues/majors"

# %%
def get_date_time():
    return datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")

# %%
def log(message):
    print(f"[*] {get_date_time()} - {message}")

# %%
def get_yearly_statistics(year):
    log(f"getting statistics for year: {year}")
    url = f"{BASE_URL}/{year}.shtml"
    log(f"url={url}")
    response = requests.get(url)
    bs = BeautifulSoup(response.text, "html.parser")
    
    table = bs.find_all('table', {'id': 'teams_standard_batting'})
    rows = []
    for tbl in table:
        for tr in tbl.find_all('tr'):
            row = []
            team = tr.find('th').text
            if team.lower() != "league average":
                row.append(year)
                row.append(team)
                for td in tr.find_all('td'):
                    row.append(td.text.replace('\n', ''))
                if len(row) == 30 and row[0] != "":
                    rows.append(row)

    return pd.DataFrame(rows, columns=['YEAR', 'TM', '#BAT', 'BATAGE', 'RPG', 'G',
                                          'PA', 'AB', 'R', 'H', '2B',
                                          '3B', 'HR', 'RBI', 'SB', 'CS',
                                          'BB', 'SO', 'BA', 'OBP', 'SLG',
                                          'OPS', 'OPS+', 'TB', 'GDP', 'HBP',
                                          'SH', 'SF', 'IBB', 'LOB'])

# %%
statistics = []
for year in range(2000, 2022):
    statistics.append(get_yearly_statistics(year))
    log("sleeping")
    time.sleep(10)
    
df = pd.concat(statistics)
# Out:
# [*] 2022-05-12 14:02:25.438880 - getting statistics for year: 2000
# [*] 2022-05-12 14:02:25.439188 - url=https://www.baseball-reference.com/leagues/majors/2000.shtml
# [*] 2022-05-12 14:02:25.815133 - sleeping
# [*] 2022-05-12 14:02:35.819364 - getting statistics for year: 2001
# [*] 2022-05-12 14:02:35.819632 - url=https://www.baseball-reference.com/leagues/majors/2001.shtml
# [*] 2022-05-12 14:02:36.077657 - sleeping
# [*] 2022-05-12 14:02:46.081590 - getting statistics for year: 2002
# [*] 2022-05-12 14:02:46.081709 - url=https://www.baseball-reference.com/leagues/majors/2002.shtml
# [*] 2022-05-12 14:02:46.324805 - sleeping
# [*] 2022-05-12 14:02:56.329358 - getting statistics for year: 2003
# [*] 2022-05-12 14:02:56.329624 - url=https://www.baseball-reference.com/leagues/majors/2003.shtml
# [*] 2022-05-12 14:02:56.588216 - sleeping
# [*] 2022-05-12 14:03:06.593702 - getting statistics for year: 2004
# [*] 2022-05-12 14:03:06.593973 - url=https://www.baseball-reference.com/leagues/majors/2004.shtml
# [*] 2022-05-12 14:03:06.892368 - sleeping
# [*] 2022-05-12 14:03:16.895009 - getting statistics for year: 2005
# [*] 2022-05-12 14:03:16.895207 - url=https://www.baseball-reference.com/leagues/majors/2005.shtml
# [*] 2022-05-12 14:03:17.129426 - sleeping
# [*] 2022-05-12 14:03:27.132018 - getting statistics for year: 2006
# [*] 2022-05-12 14:03:27.132295 - url=https://www.baseball-reference.com/leagues/majors/2006.shtml
# [*] 2022-05-12 14:03:27.459712 - sleeping
# [*] 2022-05-12 14:03:37.465069 - getting statistics for year: 2007
# [*] 2022-05-12 14:03:37.465346 - url=https://www.baseball-reference.com/leagues/majors/2007.shtml
# [*] 2022-05-12 14:03:37.728481 - sleeping
# [*] 2022-05-12 14:03:47.732438 - getting statistics for year: 2008
# [*] 2022-05-12 14:03:47.732615 - url=https://www.baseball-reference.com/leagues/majors/2008.shtml
# [*] 2022-05-12 14:03:48.088392 - sleeping
# [*] 2022-05-12 14:03:58.093312 - getting statistics for year: 2009
# [*] 2022-05-12 14:03:58.093692 - url=https://www.baseball-reference.com/leagues/majors/2009.shtml
# [*] 2022-05-12 14:03:58.364641 - sleeping
# [*] 2022-05-12 14:04:08.367485 - getting statistics for year: 2010
# [*] 2022-05-12 14:04:08.367737 - url=https://www.baseball-reference.com/leagues/majors/2010.shtml
# [*] 2022-05-12 14:04:08.606802 - sleeping
# [*] 2022-05-12 14:04:18.608327 - getting statistics for year: 2011
# [*] 2022-05-12 14:04:18.608525 - url=https://www.baseball-reference.com/leagues/majors/2011.shtml
# [*] 2022-05-12 14:04:18.854431 - sleeping
# [*] 2022-05-12 14:04:28.858950 - getting statistics for year: 2012
# [*] 2022-05-12 14:04:28.859287 - url=https://www.baseball-reference.com/leagues/majors/2012.shtml
# [*] 2022-05-12 14:04:29.168832 - sleeping
# [*] 2022-05-12 14:04:39.170756 - getting statistics for year: 2013
# [*] 2022-05-12 14:04:39.171079 - url=https://www.baseball-reference.com/leagues/majors/2013.shtml
# [*] 2022-05-12 14:04:39.418551 - sleeping
# [*] 2022-05-12 14:04:49.421538 - getting statistics for year: 2014
# [*] 2022-05-12 14:04:49.421849 - url=https://www.baseball-reference.com/leagues/majors/2014.shtml
# [*] 2022-05-12 14:04:49.662066 - sleeping
# [*] 2022-05-12 14:04:59.664160 - getting statistics for year: 2015
# [*] 2022-05-12 14:04:59.664434 - url=https://www.baseball-reference.com/leagues/majors/2015.shtml
# [*] 2022-05-12 14:04:59.919128 - sleeping
# [*] 2022-05-12 14:05:09.924838 - getting statistics for year: 2016
# [*] 2022-05-12 14:05:09.925127 - url=https://www.baseball-reference.com/leagues/majors/2016.shtml
# [*] 2022-05-12 14:05:10.280301 - sleeping
# [*] 2022-05-12 14:05:20.282767 - getting statistics for year: 2017
# [*] 2022-05-12 14:05:20.283044 - url=https://www.baseball-reference.com/leagues/majors/2017.shtml
# [*] 2022-05-12 14:05:20.525010 - sleeping
# [*] 2022-05-12 14:05:30.527118 - getting statistics for year: 2018
# [*] 2022-05-12 14:05:30.527457 - url=https://www.baseball-reference.com/leagues/majors/2018.shtml
# [*] 2022-05-12 14:05:30.835625 - sleeping
# [*] 2022-05-12 14:05:40.840216 - getting statistics for year: 2019
# [*] 2022-05-12 14:05:40.840489 - url=https://www.baseball-reference.com/leagues/majors/2019.shtml
# [*] 2022-05-12 14:05:41.098913 - sleeping
# [*] 2022-05-12 14:05:51.102585 - getting statistics for year: 2020
# [*] 2022-05-12 14:05:51.102932 - url=https://www.baseball-reference.com/leagues/majors/2020.shtml
# [*] 2022-05-12 14:05:51.356936 - sleeping
# [*] 2022-05-12 14:06:01.360282 - getting statistics for year: 2021
# [*] 2022-05-12 14:06:01.360560 - url=https://www.baseball-reference.com/leagues/majors/2021.shtml
# [*] 2022-05-12 14:06:01.630016 - sleeping

# %%
df.head()
# Out:
#    YEAR                    TM #BAT BATAGE   RPG    G    PA    AB    R     H  \
# 0  2000        Anaheim Angels   45   27.6  5.33  162  6373  5628  864  1574
# 1  2000  Arizona Diamondbacks   41   30.8  4.89  162  6241  5527  792  1466
# 2  2000        Atlanta Braves   47   30.8  5.00  162  6275  5489  810  1490
# 3  2000     Baltimore Orioles   50   32.1  4.90  162  6238  5549  794  1508
# 4  2000        Boston Red Sox   52   29.3  4.89  162  6371  5630  792  1503
#
#    ...   SLG   OPS OPS+    TB  GDP HBP  SH  SF IBB   LOB
# 0  ...  .472  .825  105  2659  126  47  47  43  43  1173
# 1  ...  .429  .763   88  2373  114  59  61  58  37  1128
# 2  ...  .429  .775   95  2353  127  59  87  45  38  1192
# 3  ...  .435  .776  100  2414  148  49  27  54  34  1129
# 4  ...  .423  .764   90  2384  115  42  40  48  40  1226
#
# [5 rows x 30 columns]

# %%
df.to_excel("yearly_batting_2000_2021.xlsx", index=False)
